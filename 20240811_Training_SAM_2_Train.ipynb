# %% [markdown]
# https://medium.com/@sagieppel/train-fine-tune-segment-anything-2-sam-2-in-60-lines-of-code-928dd29a63b3

# %%
import numpy as np
import torch
import cv2
import os
from sam2.build_sam import build_sam2
from sam2.sam2_image_predictor import SAM2ImagePredictor
# Out:
# OLD_GPU False, USE_FLASH_ATTN True, MATH_KERNEL_ON False

# %%
data_dir=r"LabPicsV1//" # Path to LabPics1 dataset folder
data=[] # list of files in dataset
for ff, name in enumerate(os.listdir(data_dir+"Simple/Train/Image/")):  # go over all folder annotation
    data.append({"image":data_dir+"Simple/Train/Image/"+name,"annotation":data_dir+"Simple/Train/Instance/"+name[:-4]+".png"})

# %%
data[0]
# Out:
# {'image': 'LabPicsV1//Simple/Train/Image/3 Summer Sangria Recipes-screenshot (2).jpg',
#  'annotation': 'LabPicsV1//Simple/Train/Instance/3 Summer Sangria Recipes-screenshot (2).png'}

# %%
def read_batch(data): # read random image and its annotaion from  the dataset (LabPics)

   #  select image

        ent  = data[np.random.randint(len(data))] # choose random entry
        Img = cv2.imread(ent["image"])[...,::-1]  # read image
        ann_map = cv2.imread(ent["annotation"]) # read annotation

   # resize image

        r = np.min([1024 / Img.shape[1], 1024 / Img.shape[0]]) # scalling factor
        Img = cv2.resize(Img, (int(Img.shape[1] * r), int(Img.shape[0] * r)))
        ann_map = cv2.resize(ann_map, (int(ann_map.shape[1] * r), int(ann_map.shape[0] * r)),interpolation=cv2.INTER_NEAREST)

   # merge vessels and materials annotations

        mat_map = ann_map[:,:,0] # material annotation map
        ves_map = ann_map[:,:,2] # vessel  annotaion map
        mat_map[mat_map==0] = ves_map[mat_map==0]*(mat_map.max()+1) # merged map

   # Get binary masks and points

        inds = np.unique(mat_map)[1:] # load all indices
        points= []
        masks = [] 
        for ind in inds:
            mask=(mat_map == ind).astype(np.uint8) # make binary mask
            masks.append(mask)
            coords = np.argwhere(mask > 0) # get all coordinates in mask
            yx = np.array(coords[np.random.randint(len(coords))]) # choose random point/coordinate
            points.append([[yx[1], yx[0]]])
        return Img,np.array(masks),np.array(points), np.ones([len(masks),1])

# %%
sam2_checkpoint = "sam2_hiera_small.pt" # path to model weight
model_cfg = "sam2_hiera_s.yaml" # model config
sam2_model = build_sam2(model_cfg, sam2_checkpoint, device="cuda") # load model
predictor = SAM2ImagePredictor(sam2_model) # load net

# %%
sam2_checkpoint = "sam2_hiera_large.pt" # path to model weight
model_cfg = "sam2_hiera_l.yaml" # model config
sam2_model = build_sam2(model_cfg, sam2_checkpoint, device="cuda") # load model
predictor = SAM2ImagePredictor(sam2_model) # load net

# %%
predictor.model.sam_mask_decoder.train(True) # enable training of mask decoder 
predictor.model.sam_prompt_encoder.train(True) # enable training of prompt encoder
# Out:
# PromptEncoder(
#   (pe_layer): PositionEmbeddingRandom()
#   (point_embeddings): ModuleList(
#     (0-3): 4 x Embedding(1, 256)
#   )
#   (not_a_point_embed): Embedding(1, 256)
#   (mask_downscaling): Sequential(
#     (0): Conv2d(1, 4, kernel_size=(2, 2), stride=(2, 2))
#     (1): LayerNorm2d()
#     (2): GELU(approximate='none')
#     (3): Conv2d(4, 16, kernel_size=(2, 2), stride=(2, 2))
#     (4): LayerNorm2d()
#     (5): GELU(approximate='none')
#     (6): Conv2d(16, 256, kernel_size=(1, 1), stride=(1, 1))
#   )
#   (no_mask_embed): Embedding(1, 256)
# )

# %%
optimizer=torch.optim.AdamW(params=predictor.model.parameters(),lr=1e-5,weight_decay=4e-5)

# %%
scaler = torch.cuda.amp.GradScaler() # set mixed precision

# %%
for itr in range(100000):
    with torch.cuda.amp.autocast(): # cast to mix precision
        #with torch.cuda.amp.autocast():
            image,mask,input_point, input_label = read_batch(data) # load data batch
            if mask.shape[0]==0: continue # ignore empty batches
            predictor.set_image(image) # apply SAM image encodet to the image

            # prompt encoding

            mask_input, unnorm_coords, labels, unnorm_box = predictor._prep_prompts(input_point, input_label, box=None, mask_logits=None, normalize_coords=True)
            sparse_embeddings, dense_embeddings = predictor.model.sam_prompt_encoder(points=(unnorm_coords, labels),boxes=None,masks=None,)

            # mask decoder

            batched_mode = unnorm_coords.shape[0] > 1 # multi object prediction
            high_res_features = [feat_level[-1].unsqueeze(0) for feat_level in predictor._features["high_res_feats"]]
            low_res_masks, prd_scores, _, _ = predictor.model.sam_mask_decoder(image_embeddings=predictor._features["image_embed"][-1].unsqueeze(0),image_pe=predictor.model.sam_prompt_encoder.get_dense_pe(),sparse_prompt_embeddings=sparse_embeddings,dense_prompt_embeddings=dense_embeddings,multimask_output=True,repeat_image=batched_mode,high_res_features=high_res_features,)
            prd_masks = predictor._transforms.postprocess_masks(low_res_masks, predictor._orig_hw[-1])# Upscale the masks to the original image resolution

            # Segmentaion Loss caclulation

            gt_mask = torch.tensor(mask.astype(np.float32)).cuda()
            prd_mask = torch.sigmoid(prd_masks[:, 0])
            seg_loss = (-gt_mask * torch.log(prd_mask + 0.00001) - (1 - gt_mask) * torch.log((1 - prd_mask) + 0.00001)).mean()

            # Score loss calculation (intersection over union) IOU

            inter = (gt_mask * (prd_mask > 0.5)).sum(1).sum(1)
            iou = inter / (gt_mask.sum(1).sum(1) + (prd_mask > 0.5).sum(1).sum(1) - inter)
            score_loss = torch.abs(prd_scores[:, 0] - iou).mean()
            loss=seg_loss+score_loss*0.05  # mix losses

            # apply back propogation

            predictor.model.zero_grad() # empty gradient
            scaler.scale(loss).backward()  # Backpropogate
            scaler.step(optimizer)
            scaler.update() # Mix precision

            if itr%1000==0: torch.save(predictor.model.state_dict(), "model.torch") # save model

            # Display results

            if itr==0: mean_iou=0
            mean_iou = mean_iou * 0.99 + 0.01 * np.mean(iou.cpu().detach().numpy())
            print("step)",itr, "Accuracy(IOU)=",mean_iou)
# Out:
# D:\workspace\20240810_Segment_Anything_2\segment-anything-2\sam2\modeling\backbones\hieradet.py:68: UserWarning: 1Torch was not compiled with flash attention. (Triggered internally at ..\aten\src\ATen\native\transformers\cuda\sdp_utils.cpp:455.)
#   x = F.scaled_dot_product_attention(
# step) 0 Accuracy(IOU)= 0.0031853342056274415
# step) 1 Accuracy(IOU)= 0.006621934151649475
# step) 2 Accuracy(IOU)= 0.011972447836637496
# step) 3 Accuracy(IOU)= 0.018381081817743776
# step) 4 Accuracy(IOU)= 0.02106248594345214
# step) 5 Accuracy(IOU)= 0.026270773256335124
# step) 6 Accuracy(IOU)= 0.026839536460308563
# step) 7 Accuracy(IOU)= 0.03097707024390265
# step) 8 Accuracy(IOU)= 0.03639326325320221
# step) 9 Accuracy(IOU)= 0.040834522972011435
# step) 10 Accuracy(IOU)= 0.04563225126485907
# step) 11 Accuracy(IOU)= 0.05019984809615884
# step) 12 Accuracy(IOU)= 0.051453161402325705
# step) 13 Accuracy(IOU)= 0.05688075034036544
# step) 14 Accuracy(IOU)= 0.05813555454345706
# step) 15 Accuracy(IOU)= 0.06561236609797519
# step) 16 Accuracy(IOU)= 0.07376550316297048
# step) 17 Accuracy(IOU)= 0.07894744289605025
# step) 18 Accuracy(IOU)= 0.0866567325051757
# step) 19 Accuracy(IOU)= 0.09356313657180179
# step) 20 Accuracy(IOU)= 0.0972332759132142
# step) 21 Accuracy(IOU)= 0.09878705922721363
# step) 22 Accuracy(IOU)= 0.10322774245459787
# step) 23 Accuracy(IOU)= 0.10322139813182515
# step) 24 Accuracy(IOU)= 0.10628319176178162
# step) 25 Accuracy(IOU)= 0.11366352347751037
# step) 26 Accuracy(IOU)= 0.11353775001205385
# step) 27 Accuracy(IOU)= 0.11539886370570468
# step) 28 Accuracy(IOU)= 0.12002313947199082
# step) 29 Accuracy(IOU)= 0.12470223930838817
# step) 30 Accuracy(IOU)= 0.1280618250676938
# step) 31 Accuracy(IOU)= 0.13057265916524916
# step) 32 Accuracy(IOU)= 0.13430264231232805
# step) 33 Accuracy(IOU)= 0.1383703604370487
# step) 34 Accuracy(IOU)= 0.14131373171804656
# step) 35 Accuracy(IOU)= 0.14184565161417254
# step) 36 Accuracy(IOU)= 0.14735801961623454
# step) 37 Accuracy(IOU)= 0.15192339665826954
# step) 38 Accuracy(IOU)= 0.15571376829013656
# step) 39 Accuracy(IOU)= 0.15851747062979912
# step) 40 Accuracy(IOU)= 0.16141662246492494
# step) 41 Accuracy(IOU)= 0.16245688204012235
# step) 42 Accuracy(IOU)= 0.16330820239585142
# step) 43 Accuracy(IOU)= 0.16703383662135884
# step) 44 Accuracy(IOU)= 0.17054954700125427
# step) 45 Accuracy(IOU)= 0.1722277842673524
# step) 46 Accuracy(IOU)= 0.17579157891727837
# step) 47 Accuracy(IOU)= 0.1750445564878859
# step) 48 Accuracy(IOU)= 0.17651232543487838
# step) 49 Accuracy(IOU)= 0.17873136945834256
# step) 50 Accuracy(IOU)= 0.1806136687674899
# step) 51 Accuracy(IOU)= 0.1853178500014535
# step) 52 Accuracy(IOU)= 0.19142297042302406
# step) 53 Accuracy(IOU)= 0.1976530383185863
# step) 54 Accuracy(IOU)= 0.2019303023670868
# step) 55 Accuracy(IOU)= 0.20647735099556133
# step) 56 Accuracy(IOU)= 0.2099577573295083
# step) 57 Accuracy(IOU)= 0.2108724000535498
# step) 58 Accuracy(IOU)= 0.21298015273186258
# step) 59 Accuracy(IOU)= 0.21707668756452167
# step) 60 Accuracy(IOU)= 0.2208957404539674
# step) 61 Accuracy(IOU)= 0.22515771899017023
# step) 62 Accuracy(IOU)= 0.22820189945159755
# step) 63 Accuracy(IOU)= 0.23099989373222807
# step) 64 Accuracy(IOU)= 0.2357342780823356
# step) 65 Accuracy(IOU)= 0.23585303681918954
# step) 66 Accuracy(IOU)= 0.23840277222047931
# step) 67 Accuracy(IOU)= 0.2414089713392474
# step) 68 Accuracy(IOU)= 0.24256729852744338
# step) 69 Accuracy(IOU)= 0.2450277502722791
# step) 70 Accuracy(IOU)= 0.25033720418149025
# step) 71 Accuracy(IOU)= 0.25345438622922156
# step) 72 Accuracy(IOU)= 0.2552350150988057
# step) 73 Accuracy(IOU)= 0.2586411267092923
# step) 74 Accuracy(IOU)= 0.2590320795054623
# step) 75 Accuracy(IOU)= 0.2595870517077679
# step) 76 Accuracy(IOU)= 0.26510601621457025
# step) 77 Accuracy(IOU)= 0.27054473984015187
# step) 78 Accuracy(IOU)= 0.2698261819828995
# step) 79 Accuracy(IOU)= 0.27454440690318277
# step) 80 Accuracy(IOU)= 0.2764042358424975
# step) 81 Accuracy(IOU)= 0.2784333185770558
# step) 82 Accuracy(IOU)= 0.281733303552296
# step) 83 Accuracy(IOU)= 0.2873257281309088
# step) 84 Accuracy(IOU)= 0.2883960086213015
# step) 85 Accuracy(IOU)= 0.291559457711915
# step) 86 Accuracy(IOU)= 0.29314856343787354
# step) 87 Accuracy(IOU)= 0.2937336269735121
# step) 88 Accuracy(IOU)= 0.29310482076621397
# step) 89 Accuracy(IOU)= 0.29760287700591664
# step) 90 Accuracy(IOU)= 0.30153245879722834
# step) 91 Accuracy(IOU)= 0.30363103332100383
# step) 92 Accuracy(IOU)= 0.30589305019535906
# step) 93 Accuracy(IOU)= 0.30648256917393907
# step) 94 Accuracy(IOU)= 0.31184511069258786
# step) 95 Accuracy(IOU)= 0.31523269133729465
# step) 96 Accuracy(IOU)= 0.3177989705383092
# step) 97 Accuracy(IOU)= 0.32090225777422554
# step) 98 Accuracy(IOU)= 0.3221905650872113
# step) 99 Accuracy(IOU)= 0.32480751792156104
# step) 100 Accuracy(IOU)= 0.3283862047033287
# step) 101 Accuracy(IOU)= 0.3333635935098339
# step) 102 Accuracy(IOU)= 0.3344728368343219
# step) 103 Accuracy(IOU)= 0.335903877580473
# step) 104 Accuracy(IOU)= 0.34122486772007354
# step) 105 Accuracy(IOU)= 0.34167310131835876
# step) 106 Accuracy(IOU)= 0.3465607802859491
# step) 107 Accuracy(IOU)= 0.3471114422265322
# step) 108 Accuracy(IOU)= 0.35075183724659625
# step) 109 Accuracy(IOU)= 0.3508053563549614
# step) 110 Accuracy(IOU)= 0.3520203968971323
# step) 111 Accuracy(IOU)= 0.3531557141421693
# step) 112 Accuracy(IOU)= 0.35615943615552514
# step) 113 Accuracy(IOU)= 0.35661286222405797
# step) 114 Accuracy(IOU)= 0.35520706222845005
# step) 115 Accuracy(IOU)= 0.35684325108854925
# step) 116 Accuracy(IOU)= 0.35754523000945315
# step) 117 Accuracy(IOU)= 0.3576896770657238
# step) 118 Accuracy(IOU)= 0.3616531958205029
# step) 119 Accuracy(IOU)= 0.3625233558140496
# step) 120 Accuracy(IOU)= 0.36221561307202543
# step) 121 Accuracy(IOU)= 0.36336800118034934
# step) 122 Accuracy(IOU)= 0.36624779813635744
# step) 123 Accuracy(IOU)= 0.3679953667324474
# step) 124 Accuracy(IOU)= 0.37227616352574766
# step) 125 Accuracy(IOU)= 0.3764769238860346
# step) 126 Accuracy(IOU)= 0.37907858338004624
# step) 127 Accuracy(IOU)= 0.38069435784802647
# step) 128 Accuracy(IOU)= 0.38574804704676025
# step) 129 Accuracy(IOU)= 0.38903008006887685
# step) 130 Accuracy(IOU)= 0.3916975257977673
# step) 131 Accuracy(IOU)= 0.39177105081110997
# step) 132 Accuracy(IOU)= 0.3932545379748891
# step) 133 Accuracy(IOU)= 0.39472881217712563
# step) 134 Accuracy(IOU)= 0.39591521190916756
# step) 135 Accuracy(IOU)= 0.4006356953148256
# step) 136 Accuracy(IOU)= 0.4005373860377638
# step) 137 Accuracy(IOU)= 0.40228785986987575
# step) 138 Accuracy(IOU)= 0.3988818161799008
# step) 139 Accuracy(IOU)= 0.4019410100363055
# step) 140 Accuracy(IOU)= 0.40637864251082495
# step) 141 Accuracy(IOU)= 0.4080293035840382
# step) 142 Accuracy(IOU)= 0.40904940563162523
# step) 143 Accuracy(IOU)= 0.41196058694266435
# step) 144 Accuracy(IOU)= 0.41299180109009864
# step) 145 Accuracy(IOU)= 0.4151517180553939
# step) 146 Accuracy(IOU)= 0.41328648246053334
# step) 147 Accuracy(IOU)= 0.4127934360658749
# step) 148 Accuracy(IOU)= 0.41680452846627114
# step) 149 Accuracy(IOU)= 0.4156516970883734
# step) 150 Accuracy(IOU)= 0.4116645890349167
# step) 151 Accuracy(IOU)= 0.4120289529855328
# step) 152 Accuracy(IOU)= 0.4102283626834874
# step) 153 Accuracy(IOU)= 0.4110309801439366
# step) 154 Accuracy(IOU)= 0.413676031899504
# step) 155 Accuracy(IOU)= 0.4129702946417844
# step) 156 Accuracy(IOU)= 0.4159543690944297
# step) 157 Accuracy(IOU)= 0.4182942547486163
# step) 158 Accuracy(IOU)= 0.41908056395302984
# step) 159 Accuracy(IOU)= 0.42306599267800915
# step) 160 Accuracy(IOU)= 0.4235744500755813
# step) 161 Accuracy(IOU)= 0.4236063135021479
# step) 162 Accuracy(IOU)= 0.4251781156291579
# step) 163 Accuracy(IOU)= 0.42565228721735027
# step) 164 Accuracy(IOU)= 0.4258814355673867
# step) 165 Accuracy(IOU)= 0.42775391438931754
# step) 166 Accuracy(IOU)= 0.428998846315714
# step) 167 Accuracy(IOU)= 0.4280781325880076
# step) 168 Accuracy(IOU)= 0.4296297837705962
# step) 169 Accuracy(IOU)= 0.4312601080852187
# step) 170 Accuracy(IOU)= 0.4308996442361933
# step) 171 Accuracy(IOU)= 0.43445885548693136
# step) 172 Accuracy(IOU)= 0.43469003742938417
# step) 173 Accuracy(IOU)= 0.43900760617797696
# step) 174 Accuracy(IOU)= 0.44084167242920075
# step) 175 Accuracy(IOU)= 0.43944417748120346
# step) 176 Accuracy(IOU)= 0.4395446051173831
# step) 177 Accuracy(IOU)= 0.4400043764038176
# step) 178 Accuracy(IOU)= 0.4422727441330808
# step) 179 Accuracy(IOU)= 0.4472182789827046
# step) 180 Accuracy(IOU)= 0.448661584197562
# step) 181 Accuracy(IOU)= 0.4479895222720407
# step) 182 Accuracy(IOU)= 0.4478350851586991
# step) 183 Accuracy(IOU)= 0.4528683445766586
# step) 184 Accuracy(IOU)= 0.45364157474993344
# step) 185 Accuracy(IOU)= 0.4544538086234439
# step) 186 Accuracy(IOU)= 0.45640328897268767
# step) 187 Accuracy(IOU)= 0.45641030768055596
# step) 188 Accuracy(IOU)= 0.4586081745277235
# step) 189 Accuracy(IOU)= 0.46376039918560635
# step) 190 Accuracy(IOU)= 0.46324094954069317
# step) 191 Accuracy(IOU)= 0.46421412681248286
# step) 192 Accuracy(IOU)= 0.4651764815465553
# step) 193 Accuracy(IOU)= 0.4689754453859512
# step) 194 Accuracy(IOU)= 0.4692343939827051
# step) 195 Accuracy(IOU)= 0.4714002200753793
# step) 196 Accuracy(IOU)= 0.47091309258375486
# step) 197 Accuracy(IOU)= 0.4713820370906947
# step) 198 Accuracy(IOU)= 0.47077556057230774
# step) 199 Accuracy(IOU)= 0.4719206747156539
# step) 200 Accuracy(IOU)= 0.4685527466907836
# step) 201 Accuracy(IOU)= 0.4726733268641422
# step) 202 Accuracy(IOU)= 0.4772644553909262
# step) 203 Accuracy(IOU)= 0.4756257419969901
# step) 204 Accuracy(IOU)= 0.47563169005854944
# step) 205 Accuracy(IOU)= 0.47725967195938607
# step) 206 Accuracy(IOU)= 0.47817101171649967
# step) 207 Accuracy(IOU)= 0.47489146709568403
# step) 208 Accuracy(IOU)= 0.47727606134539674
# step) 209 Accuracy(IOU)= 0.4772198934610344
# step) 210 Accuracy(IOU)= 0.47499821899961436
# step) 211 Accuracy(IOU)= 0.47443476215446684
# step) 212 Accuracy(IOU)= 0.47086422221352897
# step) 213 Accuracy(IOU)= 0.4703036320281559
# step) 214 Accuracy(IOU)= 0.4704140599918175
# step) 215 Accuracy(IOU)= 0.4713135535109331
# step) 216 Accuracy(IOU)= 0.4698467035931753
# step) 217 Accuracy(IOU)= 0.47010075847744776
# step) 218 Accuracy(IOU)= 0.4709174488230093
# step) 219 Accuracy(IOU)= 0.47280597206961195
# step) 220 Accuracy(IOU)= 0.4716156345788734
# step) 221 Accuracy(IOU)= 0.4715173504712438
# step) 222 Accuracy(IOU)= 0.4685466004751755
# step) 223 Accuracy(IOU)= 0.4646744758346882
# step) 224 Accuracy(IOU)= 0.46645436407671514
# step) 225 Accuracy(IOU)= 0.46901625061363655
# step) 226 Accuracy(IOU)= 0.4734992447265722
# step) 227 Accuracy(IOU)= 0.47528736791422466
# step) 228 Accuracy(IOU)= 0.47386991234020787
# step) 229 Accuracy(IOU)= 0.4737759200620893
# step) 230 Accuracy(IOU)= 0.4742051021466017
# step) 231 Accuracy(IOU)= 0.474196015760031
# step) 232 Accuracy(IOU)= 0.4728289382408851
# step) 233 Accuracy(IOU)= 0.4737989512466675
# step) 234 Accuracy(IOU)= 0.47836089147224553
# step) 235 Accuracy(IOU)= 0.4804533190822957
# step) 236 Accuracy(IOU)= 0.4796215323233003
# step) 237 Accuracy(IOU)= 0.47853673699966676
# step) 238 Accuracy(IOU)= 0.4775397821410188
# step) 239 Accuracy(IOU)= 0.4801659788392238
# step) 240 Accuracy(IOU)= 0.48063172277264093
# step) 241 Accuracy(IOU)= 0.4822856507965701
# step) 242 Accuracy(IOU)= 0.48335898111721765
# step) 243 Accuracy(IOU)= 0.4874774415150909
# step) 244 Accuracy(IOU)= 0.4885594837732188
# step) 245 Accuracy(IOU)= 0.4904465763706367
# step) 246 Accuracy(IOU)= 0.49127958278348216
# step) 247 Accuracy(IOU)= 0.4926060271251725
# step) 248 Accuracy(IOU)= 0.49326480405217815
# step) 249 Accuracy(IOU)= 0.4965928900929247
# step) 250 Accuracy(IOU)= 0.49876552995095996
# step) 251 Accuracy(IOU)= 0.49783177489330216
# step) 252 Accuracy(IOU)= 0.49690312426434896
# step) 253 Accuracy(IOU)= 0.5004432157510069
# step) 254 Accuracy(IOU)= 0.5042738263085695
# step) 255 Accuracy(IOU)= 0.5048160057100117
# step) 256 Accuracy(IOU)= 0.5067691389544939
# step) 257 Accuracy(IOU)= 0.5094337840860976
# step) 258 Accuracy(IOU)= 0.5089309955821468
# step) 259 Accuracy(IOU)= 0.5081139939759347
# step) 260 Accuracy(IOU)= 0.5078884096301428
# step) 261 Accuracy(IOU)= 0.506624408765958
# step) 262 Accuracy(IOU)= 0.5069259456021419
# step) 263 Accuracy(IOU)= 0.5107588627646965
# step) 264 Accuracy(IOU)= 0.5124987588448819
# step) 265 Accuracy(IOU)= 0.515198126620279
# step) 266 Accuracy(IOU)= 0.5151601398332556
# step) 267 Accuracy(IOU)= 0.5130423466066721
# step) 268 Accuracy(IOU)= 0.5149793102446398
# step) 269 Accuracy(IOU)= 0.5132343222063948
# step) 270 Accuracy(IOU)= 0.512740067925905
# step) 271 Accuracy(IOU)= 0.5169994212825956
# step) 272 Accuracy(IOU)= 0.5168948825064762
# step) 273 Accuracy(IOU)= 0.520497277508659
# step) 274 Accuracy(IOU)= 0.5213088220151048
# step) 275 Accuracy(IOU)= 0.5190028272602819
# step) 276 Accuracy(IOU)= 0.5198156101811453
# step) 277 Accuracy(IOU)= 0.522440663841907
# step) 278 Accuracy(IOU)= 0.5224108753093764
# step) 279 Accuracy(IOU)= 0.52182080774643
# step) 280 Accuracy(IOU)= 0.5244277602915625
# step) 281 Accuracy(IOU)= 0.5251170821606926
# step) 282 Accuracy(IOU)= 0.5287331346018725
# step) 283 Accuracy(IOU)= 0.5288536504219151
# step) 284 Accuracy(IOU)= 0.5284256912029858
# step) 285 Accuracy(IOU)= 0.5272115997462973
# step) 286 Accuracy(IOU)= 0.5278170697559524
# step) 287 Accuracy(IOU)= 0.532007048005155
# step) 288 Accuracy(IOU)= 0.5300875414208057
# step) 289 Accuracy(IOU)= 0.5320438080735532
# step) 290 Accuracy(IOU)= 0.5321525371442688
# step) 291 Accuracy(IOU)= 0.5333264553553609
# step) 292 Accuracy(IOU)= 0.5311074628598174
# step) 293 Accuracy(IOU)= 0.53273134096712
# step) 294 Accuracy(IOU)= 0.5355829852581783
# step) 295 Accuracy(IOU)= 0.5344913098398006
# step) 296 Accuracy(IOU)= 0.5362023713441019
# step) 297 Accuracy(IOU)= 0.5358501829930952
# step) 298 Accuracy(IOU)= 0.5364243335174047
# step) 299 Accuracy(IOU)= 0.5382795424441554
# step) 300 Accuracy(IOU)= 0.5396337670354304
# step) 301 Accuracy(IOU)= 0.5389079348887578
# step) 302 Accuracy(IOU)= 0.5405394208112477
# step) 303 Accuracy(IOU)= 0.5382969983381358
# step) 304 Accuracy(IOU)= 0.5391676570855284
# step) 305 Accuracy(IOU)= 0.5388843769256152
# step) 306 Accuracy(IOU)= 0.537093424487078
# step) 307 Accuracy(IOU)= 0.5371749884397627
# step) 308 Accuracy(IOU)= 0.5384637268032365
# step) 309 Accuracy(IOU)= 0.5393214041123068
# step) 310 Accuracy(IOU)= 0.5388387711830918
# step) 311 Accuracy(IOU)= 0.5398730843532188
# step) 312 Accuracy(IOU)= 0.5379862737829906
# step) 313 Accuracy(IOU)= 0.539892527525988
# step) 314 Accuracy(IOU)= 0.5417245266186328
# step) 315 Accuracy(IOU)= 0.5392986888660649
# step) 316 Accuracy(IOU)= 0.5422172984901987
# step) 317 Accuracy(IOU)= 0.5420169376343175
# step) 318 Accuracy(IOU)= 0.5444592932442414
# step) 319 Accuracy(IOU)= 0.5432606908265543
# step) 320 Accuracy(IOU)= 0.5450352153040919
# step) 321 Accuracy(IOU)= 0.542808243597485
# step) 322 Accuracy(IOU)= 0.5437220679474751
# step) 323 Accuracy(IOU)= 0.5415022767867
# step) 324 Accuracy(IOU)= 0.5407932260942954
# step) 325 Accuracy(IOU)= 0.5405763589063657
# step) 326 Accuracy(IOU)= 0.5383944433621743
# step) 327 Accuracy(IOU)= 0.5383116716618594
# step) 328 Accuracy(IOU)= 0.542146201663266
# step) 329 Accuracy(IOU)= 0.5443737923857768
# step) 330 Accuracy(IOU)= 0.5469066216110813
# step) 331 Accuracy(IOU)= 0.5481938730104795
# step) 332 Accuracy(IOU)= 0.5477053575038702
# step) 333 Accuracy(IOU)= 0.549846324105719
# step) 334 Accuracy(IOU)= 0.5483096495785938
# step) 335 Accuracy(IOU)= 0.5481229175094208
# step) 336 Accuracy(IOU)= 0.548017819868903
# step) 337 Accuracy(IOU)= 0.5502761895913946
# step) 338 Accuracy(IOU)= 0.5523957191412128
# step) 339 Accuracy(IOU)= 0.5544448807556859
# step) 340 Accuracy(IOU)= 0.5536023383907712
# step) 341 Accuracy(IOU)= 0.5520379688855523
# step) 342 Accuracy(IOU)= 0.553063795671001
# step) 343 Accuracy(IOU)= 0.5529346695026591
# step) 344 Accuracy(IOU)= 0.551059223430954
# step) 345 Accuracy(IOU)= 0.5516399701887634
# step) 346 Accuracy(IOU)= 0.5490634724348509
# step) 347 Accuracy(IOU)= 0.5476812794805791
# step) 348 Accuracy(IOU)= 0.5488463094086661
# step) 349 Accuracy(IOU)= 0.549005912716061
# step) 350 Accuracy(IOU)= 0.5492622473886822
# step) 351 Accuracy(IOU)= 0.5492260665556493
# step) 352 Accuracy(IOU)= 0.5498581557226275
# step) 353 Accuracy(IOU)= 0.5533023689652059
# step) 354 Accuracy(IOU)= 0.5542949458281128
# step) 355 Accuracy(IOU)= 0.5534703286604811
# step) 356 Accuracy(IOU)= 0.5502144775386216
# step) 357 Accuracy(IOU)= 0.5477715289373801
# step) 358 Accuracy(IOU)= 0.5454846103213042
# step) 359 Accuracy(IOU)= 0.5440725261399738
# step) 360 Accuracy(IOU)= 0.5424879880433576
# step) 361 Accuracy(IOU)= 0.5413933623600446
# step) 362 Accuracy(IOU)= 0.541254448739763
# step) 363 Accuracy(IOU)= 0.5394891169365199
# step) 364 Accuracy(IOU)= 0.5404634940653038
# step) 365 Accuracy(IOU)= 0.5397102315573595
# step) 366 Accuracy(IOU)= 0.5386194563463544
# step) 367 Accuracy(IOU)= 0.540268400389916
# step) 368 Accuracy(IOU)= 0.5434843554975356
# step) 369 Accuracy(IOU)= 0.5426044178339787
# step) 370 Accuracy(IOU)= 0.5397991019695618
# step) 371 Accuracy(IOU)= 0.5408030098107975
# step) 372 Accuracy(IOU)= 0.5409359222623951
# step) 373 Accuracy(IOU)= 0.5391919235501204
# step) 374 Accuracy(IOU)= 0.542230370234686
# step) 375 Accuracy(IOU)= 0.539956233069624
# step) 376 Accuracy(IOU)= 0.5389880916016024
# step) 377 Accuracy(IOU)= 0.5399430482319351
# step) 378 Accuracy(IOU)= 0.539363899314805
# step) 379 Accuracy(IOU)= 0.5398795828218859
# step) 380 Accuracy(IOU)= 0.5384389580036844
# step) 381 Accuracy(IOU)= 0.5406411441701837
# step) 382 Accuracy(IOU)= 0.542390252452374
# step) 383 Accuracy(IOU)= 0.5419938687962966
# step) 384 Accuracy(IOU)= 0.5424077299473534
# step) 385 Accuracy(IOU)= 0.5442332094277413
# step) 386 Accuracy(IOU)= 0.5427292634757177
# step) 387 Accuracy(IOU)= 0.543782587172061
# step) 388 Accuracy(IOU)= 0.5441498299124391
# step) 389 Accuracy(IOU)= 0.5443123108432417
# step) 390 Accuracy(IOU)= 0.5434416379553941
# step) 391 Accuracy(IOU)= 0.542443172689541
# step) 392 Accuracy(IOU)= 0.5412841730224104
# step) 393 Accuracy(IOU)= 0.5390422912416797
# step) 394 Accuracy(IOU)= 0.5390999802210095
# step) 395 Accuracy(IOU)= 0.5385698750988225
# step) 396 Accuracy(IOU)= 0.5393395384770456
# step) 397 Accuracy(IOU)= 0.5376244026438003
# step) 398 Accuracy(IOU)= 0.5409636314347832
# step) 399 Accuracy(IOU)= 0.5437623748659187
# step) 400 Accuracy(IOU)= 0.5406893131220641
# step) 401 Accuracy(IOU)= 0.5445210362189471
# step) 402 Accuracy(IOU)= 0.5450244236455684
# step) 403 Accuracy(IOU)= 0.5442938176375292
# step) 404 Accuracy(IOU)= 0.546736985236987
# step) 405 Accuracy(IOU)= 0.5443267546024707
# step) 406 Accuracy(IOU)= 0.5434059259998321
# step) 407 Accuracy(IOU)= 0.5414874822030906
# step) 408 Accuracy(IOU)= 0.5409847388097783
# step) 409 Accuracy(IOU)= 0.5418566660617637
# step) 410 Accuracy(IOU)= 0.5415413137842714
# step) 411 Accuracy(IOU)= 0.5445474546158119
# step) 412 Accuracy(IOU)= 0.5446783617530034
# step) 413 Accuracy(IOU)= 0.5448337114095517
# step) 414 Accuracy(IOU)= 0.5464138204929659
# step) 415 Accuracy(IOU)= 0.5450510984586334
# step) 416 Accuracy(IOU)= 0.547348066555201
# step) 417 Accuracy(IOU)= 0.5478149641979452
# step) 418 Accuracy(IOU)= 0.5471592833135951
# step) 419 Accuracy(IOU)= 0.5444172631342297
# step) 420 Accuracy(IOU)= 0.5449626611205631
# step) 421 Accuracy(IOU)= 0.5418836508559551
# step) 422 Accuracy(IOU)= 0.5409881479564997
# step) 423 Accuracy(IOU)= 0.5414279283040221
# step) 424 Accuracy(IOU)= 0.5389909689768076
# step) 425 Accuracy(IOU)= 0.542340809672324
# step) 426 Accuracy(IOU)= 0.5433042532439586
# step) 427 Accuracy(IOU)= 0.5434193684034746
# step) 428 Accuracy(IOU)= 0.5438235402742494
# step) 429 Accuracy(IOU)= 0.5431209636363461
# step) 430 Accuracy(IOU)= 0.5419580667522295
# step) 431 Accuracy(IOU)= 0.5412012754890994
# step) 432 Accuracy(IOU)= 0.5451125092132427
# step) 433 Accuracy(IOU)= 0.5470491783773206
# step) 434 Accuracy(IOU)= 0.5450005737528949
# step) 435 Accuracy(IOU)= 0.5442533059428027
# step) 436 Accuracy(IOU)= 0.5465823370093895
# step) 437 Accuracy(IOU)= 0.5455446991618519
# step) 438 Accuracy(IOU)= 0.5434346978627727
# step) 439 Accuracy(IOU)= 0.544423472574895
# step) 440 Accuracy(IOU)= 0.5426050596183836
# step) 441 Accuracy(IOU)= 0.5412435215730306
# step) 442 Accuracy(IOU)= 0.5414687165815282
# step) 443 Accuracy(IOU)= 0.5400177663074595
# step) 444 Accuracy(IOU)= 0.5393635590127702
# step) 445 Accuracy(IOU)= 0.541151735947438
# step) 446 Accuracy(IOU)= 0.5425994936905789
# step) 447 Accuracy(IOU)= 0.5429652957955662
# step) 448 Accuracy(IOU)= 0.5446393190375235
# step) 449 Accuracy(IOU)= 0.5427320484882349
# step) 450 Accuracy(IOU)= 0.540596879692882
# step) 451 Accuracy(IOU)= 0.5409568681322432
# step) 452 Accuracy(IOU)= 0.5424392361107336
# step) 453 Accuracy(IOU)= 0.5418596222277718
# step) 454 Accuracy(IOU)= 0.5412906518313761
# step) 455 Accuracy(IOU)= 0.5404980091875932
# step) 456 Accuracy(IOU)= 0.5447389465113361
# step) 457 Accuracy(IOU)= 0.5461164784157754
# step) 458 Accuracy(IOU)= 0.5455050083008642
# step) 459 Accuracy(IOU)= 0.5459814423210584
# step) 460 Accuracy(IOU)= 0.5466414012857567
# step) 461 Accuracy(IOU)= 0.5460625836416888
# step) 462 Accuracy(IOU)= 0.5458755842519958
# step) 463 Accuracy(IOU)= 0.5447879281795449
# step) 464 Accuracy(IOU)= 0.5432003452067438
# step) 465 Accuracy(IOU)= 0.543769647930862
# step) 466 Accuracy(IOU)= 0.5440109765055314
# step) 467 Accuracy(IOU)= 0.5445981730587592
# step) 468 Accuracy(IOU)= 0.5443743736020363
# step) 469 Accuracy(IOU)= 0.5425297508405567
# step) 470 Accuracy(IOU)= 0.5446172683307777
# step) 471 Accuracy(IOU)= 0.5450233657738127
# step) 472 Accuracy(IOU)= 0.5450634095256282
# step) 473 Accuracy(IOU)= 0.5455361831042076
# step) 474 Accuracy(IOU)= 0.5471836910222347
# step) 475 Accuracy(IOU)= 0.5483772543786597
# step) 476 Accuracy(IOU)= 0.5480217403015937
# step) 477 Accuracy(IOU)= 0.5472668733381262
# step) 478 Accuracy(IOU)= 0.5481966256023646
# step) 479 Accuracy(IOU)= 0.5483445171248902
# step) 481 Accuracy(IOU)= 0.5480354602430929
# step) 482 Accuracy(IOU)= 0.5503024142525318
# step) 483 Accuracy(IOU)= 0.5523220434512998
# step) 484 Accuracy(IOU)= 0.5520130719124319
# step) 485 Accuracy(IOU)= 0.552677326016153
# step) 486 Accuracy(IOU)= 0.5536513536039988
# step) 487 Accuracy(IOU)= 0.5535574641600608
# step) 488 Accuracy(IOU)= 0.555200647305211
# step) 489 Accuracy(IOU)= 0.5550099153129786
# step) 490 Accuracy(IOU)= 0.55354675436223
# step) 491 Accuracy(IOU)= 0.5534221106406292
# step) 492 Accuracy(IOU)= 0.5521631316244481
# step) 493 Accuracy(IOU)= 0.5519851824781178
# step) 494 Accuracy(IOU)= 0.5526362019111185
# step) 495 Accuracy(IOU)= 0.5512101578470244
# step) 496 Accuracy(IOU)= 0.5546168452976755
# step) 497 Accuracy(IOU)= 0.5534961286002225
# step) 498 Accuracy(IOU)= 0.5503573652292973
# step) 499 Accuracy(IOU)= 0.5479752385441293
# step) 500 Accuracy(IOU)= 0.5461965277975392
# step) 501 Accuracy(IOU)= 0.5449805762801305
# step) 502 Accuracy(IOU)= 0.5481197283038893
# step) 503 Accuracy(IOU)= 0.5489005139386361
# step) 504 Accuracy(IOU)= 0.5488466942316839
# step) 505 Accuracy(IOU)= 0.5473531463510277
# step) 506 Accuracy(IOU)= 0.5449291765668807
# step) 507 Accuracy(IOU)= 0.546881315408054
# step) 508 Accuracy(IOU)= 0.5494603494057297
# step) 509 Accuracy(IOU)= 0.5515531585074214
# step) 510 Accuracy(IOU)= 0.5487111935617706
# step) 511 Accuracy(IOU)= 0.5477673228885888
# step) 512 Accuracy(IOU)= 0.5476827440801358
# step) 513 Accuracy(IOU)= 0.5487741804084842
# step) 514 Accuracy(IOU)= 0.548888403197333
# step) 515 Accuracy(IOU)= 0.5493278638919221
# step) 516 Accuracy(IOU)= 0.5470973122155692
# step) 517 Accuracy(IOU)= 0.5477959509050514
# step) 518 Accuracy(IOU)= 0.5513430298767595
# step) 519 Accuracy(IOU)= 0.5520691806860852
# step) 520 Accuracy(IOU)= 0.5535853744983878
# step) 521 Accuracy(IOU)= 0.5560964893326963
# step) 522 Accuracy(IOU)= 0.5545167535062181
# step) 523 Accuracy(IOU)= 0.5558676073372752
# step) 524 Accuracy(IOU)= 0.5566179160203721
# step) 525 Accuracy(IOU)= 0.5590307185934905
# step) 526 Accuracy(IOU)= 0.5588084301539317
# step) 527 Accuracy(IOU)= 0.5628115187859708
# step) 528 Accuracy(IOU)= 0.5623796030152254
# step) 529 Accuracy(IOU)= 0.5610786886836815
# step) 530 Accuracy(IOU)= 0.5618648588366778
# step) 531 Accuracy(IOU)= 0.5587185143540697
# step) 532 Accuracy(IOU)= 0.5569090271909329
# step) 533 Accuracy(IOU)= 0.5553449521134397
# step) 534 Accuracy(IOU)= 0.5559042688581743
# step) 535 Accuracy(IOU)= 0.5536344071636264
# step) 536 Accuracy(IOU)= 0.555752626280543
# step) 537 Accuracy(IOU)= 0.5560550710641853
# step) 538 Accuracy(IOU)= 0.553160374449956
# step) 539 Accuracy(IOU)= 0.5523463513815352
# step) 540 Accuracy(IOU)= 0.5511484172046491
# step) 541 Accuracy(IOU)= 0.5536640777030891
# step) 542 Accuracy(IOU)= 0.5546160879632744
# step) 543 Accuracy(IOU)= 0.5544574836365286
# step) 544 Accuracy(IOU)= 0.5568117353992844
# step) 545 Accuracy(IOU)= 0.5597652941088291
# step) 546 Accuracy(IOU)= 0.5578268957782794
# step) 547 Accuracy(IOU)= 0.5560664074343958
# step) 548 Accuracy(IOU)= 0.5593478921408747
# step) 549 Accuracy(IOU)= 0.5589246422968052
# step) 550 Accuracy(IOU)= 0.5587436584842725
# step) 551 Accuracy(IOU)= 0.5610542158216634
# step) 552 Accuracy(IOU)= 0.5620840626290534
# step) 553 Accuracy(IOU)= 0.5628466273305598
# step) 554 Accuracy(IOU)= 0.5640676848399843
# step) 555 Accuracy(IOU)= 0.5646172883098446
# step) 556 Accuracy(IOU)= 0.5641724736258658
# step) 557 Accuracy(IOU)= 0.5652830944515883
# step) 558 Accuracy(IOU)= 0.5672127038833542
# step) 559 Accuracy(IOU)= 0.5667449814370347
# step) 560 Accuracy(IOU)= 0.5627389921713035
# step) 561 Accuracy(IOU)= 0.5591651320187726
# step) 562 Accuracy(IOU)= 0.5627918033332818
# step) 563 Accuracy(IOU)= 0.5634057772801202
# step) 564 Accuracy(IOU)= 0.5625568209210458
# step) 565 Accuracy(IOU)= 0.5640869679389624
# step) 566 Accuracy(IOU)= 0.5664976790462778
# step) 567 Accuracy(IOU)= 0.5676225701337753
# step) 568 Accuracy(IOU)= 0.5686730945678593
# step) 569 Accuracy(IOU)= 0.5712265418496053
# step) 570 Accuracy(IOU)= 0.5700817249279279
# step) 571 Accuracy(IOU)= 0.5682007768393007
# step) 572 Accuracy(IOU)= 0.569189645812317
# step) 573 Accuracy(IOU)= 0.5728137181061012
# step) 574 Accuracy(IOU)= 0.5705246163406895
# step) 575 Accuracy(IOU)= 0.5696909153132574
# step) 576 Accuracy(IOU)= 0.5674596139224616
# step) 577 Accuracy(IOU)= 0.568142445022655
# step) 578 Accuracy(IOU)= 0.5699886914327189
# step) 579 Accuracy(IOU)= 0.5668947759143611
# step) 580 Accuracy(IOU)= 0.5621376264088729
# step) 581 Accuracy(IOU)= 0.5637133441084071
# step) 582 Accuracy(IOU)= 0.562868177344035
# step) 583 Accuracy(IOU)= 0.5599054608296699
# step) 584 Accuracy(IOU)= 0.5584754283642603
# step) 585 Accuracy(IOU)= 0.5576614715716913
# step) 586 Accuracy(IOU)= 0.5548629104376891
# step) 587 Accuracy(IOU)= 0.5529261416085808
# step) 588 Accuracy(IOU)= 0.5543053070733315
# step) 589 Accuracy(IOU)= 0.5568158768444331
# step) 590 Accuracy(IOU)= 0.5569808361332398
# step) 591 Accuracy(IOU)= 0.5583810506887013
# step) 592 Accuracy(IOU)= 0.5566326956590519
# step) 593 Accuracy(IOU)= 0.5560833309922716
# step) 594 Accuracy(IOU)= 0.5573073617503802
# step) 595 Accuracy(IOU)= 0.5581952253944578
# step) 596 Accuracy(IOU)= 0.5580529730287426
# step) 597 Accuracy(IOU)= 0.5585241106311044
# step) 598 Accuracy(IOU)= 0.5576606299765869
# step) 599 Accuracy(IOU)= 0.5529951164349998
# step) 600 Accuracy(IOU)= 0.5510918557775849
# step) 601 Accuracy(IOU)= 0.5464926238637672
# step) 602 Accuracy(IOU)= 0.5451771137141874
# step) 603 Accuracy(IOU)= 0.5448920120649987
# step) 604 Accuracy(IOU)= 0.5441483931695341
# step) 605 Accuracy(IOU)= 0.5433955005988846
# step) 606 Accuracy(IOU)= 0.5441457289520419
# step) 607 Accuracy(IOU)= 0.5470267823818209
# step) 608 Accuracy(IOU)= 0.5451878959504817
# step) 609 Accuracy(IOU)= 0.544924386145907
# step) 610 Accuracy(IOU)= 0.5450760089598248
# step) 611 Accuracy(IOU)= 0.5445837351292102
# step) 612 Accuracy(IOU)= 0.5459693720821173
# step) 613 Accuracy(IOU)= 0.545441730258345
# step) 614 Accuracy(IOU)= 0.5488308457564359
# step) 615 Accuracy(IOU)= 0.5517022335679069
# step) 616 Accuracy(IOU)= 0.5476650661139914
# step) 617 Accuracy(IOU)= 0.5487697833031551
# step) 618 Accuracy(IOU)= 0.5504213671006395
# step) 619 Accuracy(IOU)= 0.5527361711975393
# step) 620 Accuracy(IOU)= 0.5550986590291354
# step) 621 Accuracy(IOU)= 0.5545222337725002
# step) 622 Accuracy(IOU)= 0.5549387365505513
# step) 623 Accuracy(IOU)= 0.5547090977058969
# step) 624 Accuracy(IOU)= 0.5544293258120517
# step) 625 Accuracy(IOU)= 0.5535504216149053
# step) 626 Accuracy(IOU)= 0.5540672832978423
# step) 627 Accuracy(IOU)= 0.5551246336410571
# step) 628 Accuracy(IOU)= 0.5559449557460375
# step) 629 Accuracy(IOU)= 0.5591414338705001
# step) 630 Accuracy(IOU)= 0.5592751249366489
# step) 631 Accuracy(IOU)= 0.5617970930781515
# step) 632 Accuracy(IOU)= 0.5623927579496389
# step) 633 Accuracy(IOU)= 0.5646977328769709
# step) 634 Accuracy(IOU)= 0.5650016808983904
# step) 635 Accuracy(IOU)= 0.5669617252580772
# step) 636 Accuracy(IOU)= 0.565177679962131
# step) 637 Accuracy(IOU)= 0.5651039442391698
# step) 638 Accuracy(IOU)= 0.5644277260066857
# step) 639 Accuracy(IOU)= 0.5640877936391206
# step) 640 Accuracy(IOU)= 0.5633965974616101
# step) 641 Accuracy(IOU)= 0.563213435720545
# step) 642 Accuracy(IOU)= 0.5622989636977818
# step) 643 Accuracy(IOU)= 0.5588224966125789
# step) 644 Accuracy(IOU)= 0.558757173062278
# step) 645 Accuracy(IOU)= 0.558736324082319
# step) 646 Accuracy(IOU)= 0.5610872063763926
# step) 647 Accuracy(IOU)= 0.5610680278331747
# step) 648 Accuracy(IOU)= 0.5645513861605329
# step) 649 Accuracy(IOU)= 0.5642712726132586
# step) 650 Accuracy(IOU)= 0.565729218303874
# step) 651 Accuracy(IOU)= 0.5640247923174676
# step) 652 Accuracy(IOU)= 0.56561880244998
# step) 653 Accuracy(IOU)= 0.5673674651468393
# step) 654 Accuracy(IOU)= 0.5643027445077649
# step) 655 Accuracy(IOU)= 0.5624197458421939
# step) 656 Accuracy(IOU)= 0.5618083764954206
# step) 657 Accuracy(IOU)= 0.5638154046679893
# step) 658 Accuracy(IOU)= 0.5616292130923177
# step) 659 Accuracy(IOU)= 0.5598456581688073
# step) 660 Accuracy(IOU)= 0.5621855585827017
# step) 661 Accuracy(IOU)= 0.5655682017170437
# step) 662 Accuracy(IOU)= 0.565904543644728
# step) 663 Accuracy(IOU)= 0.5684201697390043
# step) 664 Accuracy(IOU)= 0.5699115685703313
# step) 665 Accuracy(IOU)= 0.568869061287357
# step) 666 Accuracy(IOU)= 0.5655202045003102
# step) 667 Accuracy(IOU)= 0.5655753592868576
# step) 668 Accuracy(IOU)= 0.5664900188066294
# step) 669 Accuracy(IOU)= 0.5675073583894524
# step) 670 Accuracy(IOU)= 0.5701022748921134
# step) 671 Accuracy(IOU)= 0.5682302551196098
# step) 672 Accuracy(IOU)= 0.5684750527499933
# step) 673 Accuracy(IOU)= 0.5712048770840199
# step) 674 Accuracy(IOU)= 0.5747312490380485
# step) 675 Accuracy(IOU)= 0.5762974842781139
# step) 676 Accuracy(IOU)= 0.5746843874603877
# step) 677 Accuracy(IOU)= 0.5754904287605351
# step) 678 Accuracy(IOU)= 0.5742801822397487
# step) 679 Accuracy(IOU)= 0.5771621403298421
# step) 680 Accuracy(IOU)= 0.5751482326616473
# step) 681 Accuracy(IOU)= 0.5741580233018925
# step) 682 Accuracy(IOU)= 0.5743083747218963
# step) 683 Accuracy(IOU)= 0.5756677291861184
# step) 684 Accuracy(IOU)= 0.5759002893219688
# step) 685 Accuracy(IOU)= 0.5770223827918167
# step) 686 Accuracy(IOU)= 0.5761450166346825
# step) 687 Accuracy(IOU)= 0.5743934439116493
# step) 688 Accuracy(IOU)= 0.5750349002310472
# step) 689 Accuracy(IOU)= 0.5749805749313581
# step) 690 Accuracy(IOU)= 0.5732473637708011
# step) 691 Accuracy(IOU)= 0.5739235886919004
# step) 692 Accuracy(IOU)= 0.5715872657197343
# step) 693 Accuracy(IOU)= 0.5692437934655598
# step) 694 Accuracy(IOU)= 0.5693611293336615
# step) 695 Accuracy(IOU)= 0.5727172191349522
# step) 696 Accuracy(IOU)= 0.5706525938166953
# step) 697 Accuracy(IOU)= 0.5703682261198003
# step) 698 Accuracy(IOU)= 0.5683414009128359
# step) 699 Accuracy(IOU)= 0.5713989079242153
# step) 700 Accuracy(IOU)= 0.5738989121559015
# step) 701 Accuracy(IOU)= 0.5703147936636531
# step) 702 Accuracy(IOU)= 0.5704110095785638
# step) 703 Accuracy(IOU)= 0.5674685531445061
# step) 704 Accuracy(IOU)= 0.5675920948040324
# step) 705 Accuracy(IOU)= 0.5660090218589027
# step) 706 Accuracy(IOU)= 0.5648979214727149
# step) 707 Accuracy(IOU)= 0.56700010132991
# step) 708 Accuracy(IOU)= 0.565388480443564
# step) 709 Accuracy(IOU)= 0.5661691453284213
# step) 710 Accuracy(IOU)= 0.5689906891151197
# step) 711 Accuracy(IOU)= 0.5644882619434881
# step) 712 Accuracy(IOU)= 0.5676274946385369
# step) 713 Accuracy(IOU)= 0.5674945041083503
# step) 714 Accuracy(IOU)= 0.5672346398530183
# step) 715 Accuracy(IOU)= 0.5680711909974415
# step) 716 Accuracy(IOU)= 0.5701557292934607
# step) 717 Accuracy(IOU)= 0.5707491049619899
# step) 718 Accuracy(IOU)= 0.567351353204038
# step) 719 Accuracy(IOU)= 0.5658843051547093
# step) 720 Accuracy(IOU)= 0.5641463179233412
# step) 721 Accuracy(IOU)= 0.5625920918637826
# step) 722 Accuracy(IOU)= 0.5632606389903795
# step) 723 Accuracy(IOU)= 0.5624207219835056
# step) 724 Accuracy(IOU)= 0.5639678499840074
# step) 725 Accuracy(IOU)= 0.5626297275349448
# step) 726 Accuracy(IOU)= 0.563928437364469
# step) 727 Accuracy(IOU)= 0.565855833302981
# step) 728 Accuracy(IOU)= 0.5687230720986285
# step) 729 Accuracy(IOU)= 0.5674227718433404
# step) 730 Accuracy(IOU)= 0.5677327884715258
# step) 731 Accuracy(IOU)= 0.5686182967570069
# step) 732 Accuracy(IOU)= 0.5671100527871824
# step) 733 Accuracy(IOU)= 0.5647041468541707
# step) 734 Accuracy(IOU)= 0.5644000651472486
# step) 735 Accuracy(IOU)= 0.5681417420718411
# step) 736 Accuracy(IOU)= 0.5671139376224286
# step) 737 Accuracy(IOU)= 0.5648669006121748
# step) 738 Accuracy(IOU)= 0.5680953033442963
# step) 739 Accuracy(IOU)= 0.5675748882689985
# step) 740 Accuracy(IOU)= 0.568812146884096
# step) 741 Accuracy(IOU)= 0.5683835756290687
# step) 742 Accuracy(IOU)= 0.5672694977515583
# step) 743 Accuracy(IOU)= 0.5664692533045718
# step) 744 Accuracy(IOU)= 0.5688796973138464
# step) 745 Accuracy(IOU)= 0.5704204162508565
# step) 746 Accuracy(IOU)= 0.5723743628804697
# step) 747 Accuracy(IOU)= 0.5700981581639614
# step) 748 Accuracy(IOU)= 0.5711290014571997
# step) 749 Accuracy(IOU)= 0.5684600657283446
# step) 750 Accuracy(IOU)= 0.5655320597885637
# step) 751 Accuracy(IOU)= 0.5691160289512677
# step) 752 Accuracy(IOU)= 0.567310281473988
# step) 753 Accuracy(IOU)= 0.5673244351146696
# step) 754 Accuracy(IOU)= 0.5694963052330511
# step) 755 Accuracy(IOU)= 0.5701495819601928
# step) 756 Accuracy(IOU)= 0.5692624486665309
# step) 757 Accuracy(IOU)= 0.5681584433524387
# step) 758 Accuracy(IOU)= 0.5717097209146114
# step) 759 Accuracy(IOU)= 0.5697518719621486
# step) 760 Accuracy(IOU)= 0.5673381355458603
# step) 761 Accuracy(IOU)= 0.5657379296803042
# step) 762 Accuracy(IOU)= 0.5649909494032193
# step) 763 Accuracy(IOU)= 0.5682409432066113
# step) 764 Accuracy(IOU)= 0.5662714239227081
# step) 765 Accuracy(IOU)= 0.5641211497092875
# step) 766 Accuracy(IOU)= 0.5634892347486403
# step) 767 Accuracy(IOU)= 0.5636370556951832
# step) 768 Accuracy(IOU)= 0.5660306228823719
# step) 769 Accuracy(IOU)= 0.5645182593157873
# step) 770 Accuracy(IOU)= 0.5639322402930335
# step) 771 Accuracy(IOU)= 0.5666473218627289
# step) 772 Accuracy(IOU)= 0.56593227920326
# step) 773 Accuracy(IOU)= 0.5669229923885909
# step) 774 Accuracy(IOU)= 0.5683179499914078
# step) 775 Accuracy(IOU)= 0.5706126280812155
# step) 776 Accuracy(IOU)= 0.5672675822979066
# step) 777 Accuracy(IOU)= 0.5685740703600441
# step) 778 Accuracy(IOU)= 0.570030654700122
# step) 779 Accuracy(IOU)= 0.5727368054580753
# step) 780 Accuracy(IOU)= 0.5729737034652773
# step) 781 Accuracy(IOU)= 0.5699070653023325
# step) 782 Accuracy(IOU)= 0.5683776721452656
# step) 783 Accuracy(IOU)= 0.566969203973217
# step) 784 Accuracy(IOU)= 0.5692677314521463
# step) 785 Accuracy(IOU)= 0.5690217533992901
# step) 786 Accuracy(IOU)= 0.5688737813725374
# step) 787 Accuracy(IOU)= 0.5694749268147706
# step) 788 Accuracy(IOU)= 0.5666312602292325
# step) 789 Accuracy(IOU)= 0.5663455334166206
# step) 790 Accuracy(IOU)= 0.5643946210335614
# step) 791 Accuracy(IOU)= 0.5649671472105396
# step) 792 Accuracy(IOU)= 0.5660936959408802
# step) 793 Accuracy(IOU)= 0.5657009375636628
# step) 794 Accuracy(IOU)= 0.5677561898648145
# step) 795 Accuracy(IOU)= 0.56874613466096
# step) 796 Accuracy(IOU)= 0.5661350040357288
# step) 797 Accuracy(IOU)= 0.566144641959048
# step) 798 Accuracy(IOU)= 0.5655674556455443
# step) 799 Accuracy(IOU)= 0.5658987082407689
# step) 800 Accuracy(IOU)= 0.5666577615531443
# step) 801 Accuracy(IOU)= 0.5677057669768966
# step) 802 Accuracy(IOU)= 0.569017474904471
# step) 803 Accuracy(IOU)= 0.5692643310668718
# step) 804 Accuracy(IOU)= 0.5691162381750567
# step) 805 Accuracy(IOU)= 0.5674009610057276
# step) 806 Accuracy(IOU)= 0.5647232989422477
# step) 807 Accuracy(IOU)= 0.5678577166152474
# step) 808 Accuracy(IOU)= 0.5677106078405134
# step) 809 Accuracy(IOU)= 0.5702511905610127
# step) 810 Accuracy(IOU)= 0.5709137442300486
# step) 811 Accuracy(IOU)= 0.5717980892821023
# step) 812 Accuracy(IOU)= 0.5710742379278173
# step) 813 Accuracy(IOU)= 0.5715698172648478
# step) 814 Accuracy(IOU)= 0.5700962126552791
# step) 815 Accuracy(IOU)= 0.570405722111139
# step) 816 Accuracy(IOU)= 0.5718022690665489
# step) 817 Accuracy(IOU)= 0.5753463319328673
# step) 818 Accuracy(IOU)= 0.5751986943953609
# step) 819 Accuracy(IOU)= 0.5728842900038402
# step) 820 Accuracy(IOU)= 0.5747747398398553
# step) 821 Accuracy(IOU)= 0.5722659294021539
# step) 822 Accuracy(IOU)= 0.5710372016400386
# step) 823 Accuracy(IOU)= 0.5704345787281381
# step) 824 Accuracy(IOU)= 0.5733857899772565
# step) 825 Accuracy(IOU)= 0.5717181013394164
# step) 826 Accuracy(IOU)= 0.5740725944345275
# step) 827 Accuracy(IOU)= 0.5762806068267453
# step) 828 Accuracy(IOU)= 0.5775632354718414
# step) 829 Accuracy(IOU)= 0.5765297462712673
# step) 830 Accuracy(IOU)= 0.5745633699168005
# step) 831 Accuracy(IOU)= 0.5742225059958841
# step) 832 Accuracy(IOU)= 0.5738969632984817
# step) 833 Accuracy(IOU)= 0.5715256096036836
# step) 834 Accuracy(IOU)= 0.5719001362224905
# step) 835 Accuracy(IOU)= 0.5719605728790644
# step) 836 Accuracy(IOU)= 0.5688021608548789
# step) 837 Accuracy(IOU)= 0.5678048912757491
# step) 838 Accuracy(IOU)= 0.5691553302837528
# step) 839 Accuracy(IOU)= 0.5703694846978571
# step) 840 Accuracy(IOU)= 0.5703222301089047
# step) 841 Accuracy(IOU)= 0.5697169704256897
# step) 842 Accuracy(IOU)= 0.568719008861806
# step) 843 Accuracy(IOU)= 0.5692316090125221
# step) 844 Accuracy(IOU)= 0.5692331148294404
# step) 845 Accuracy(IOU)= 0.5675255297200598
# step) 846 Accuracy(IOU)= 0.5660977341921082
# step) 847 Accuracy(IOU)= 0.5681261118659419
# step) 848 Accuracy(IOU)= 0.5699487226650071
# step) 849 Accuracy(IOU)= 0.5696032250394922
# step) 850 Accuracy(IOU)= 0.5700841049776273
# step) 851 Accuracy(IOU)= 0.5702218363107779
# step) 852 Accuracy(IOU)= 0.5682922632423364
# step) 853 Accuracy(IOU)= 0.5676408219951441
# step) 854 Accuracy(IOU)= 0.5686288019549718
# step) 855 Accuracy(IOU)= 0.5671299825237742
# step) 856 Accuracy(IOU)= 0.5644902813261038
# step) 857 Accuracy(IOU)= 0.5653867379374339
# step) 858 Accuracy(IOU)= 0.5651517594845655
# step) 859 Accuracy(IOU)= 0.5659423399112272
# step) 860 Accuracy(IOU)= 0.5649420518537592
# step) 861 Accuracy(IOU)= 0.5687185235690703
# step) 862 Accuracy(IOU)= 0.5679945229284876
# step) 863 Accuracy(IOU)= 0.5672121796016877
# step) 864 Accuracy(IOU)= 0.5677523846899406
# step) 865 Accuracy(IOU)= 0.5711852495988395
# step) 866 Accuracy(IOU)= 0.570994416203994
# step) 867 Accuracy(IOU)= 0.5687620916303292
# step) 868 Accuracy(IOU)= 0.5686465686115555
# step) 869 Accuracy(IOU)= 0.5671729946829283
# step) 870 Accuracy(IOU)= 0.5693530686349103
# step) 871 Accuracy(IOU)= 0.5691263633145813
# step) 872 Accuracy(IOU)= 0.5723383181892022
# step) 873 Accuracy(IOU)= 0.5707399373318913
# step) 874 Accuracy(IOU)= 0.5706545797800523
# step) 875 Accuracy(IOU)= 0.5704887714919793
# step) 876 Accuracy(IOU)= 0.569017818060316
# step) 877 Accuracy(IOU)= 0.5672107608933543
# step) 878 Accuracy(IOU)= 0.5653182243407867
# step) 879 Accuracy(IOU)= 0.5622330611298573
# step) 880 Accuracy(IOU)= 0.5657179399626047
# step) 881 Accuracy(IOU)= 0.5660790117436274
# step) 882 Accuracy(IOU)= 0.5677487656210947
# step) 883 Accuracy(IOU)= 0.5662209774740276
# step) 884 Accuracy(IOU)= 0.5648775328031043
# step) 885 Accuracy(IOU)= 0.5679868648988555
# step) 886 Accuracy(IOU)= 0.5702071913716321
# step) 887 Accuracy(IOU)= 0.5721931482703243
# step) 888 Accuracy(IOU)= 0.5707680095332113
# step) 889 Accuracy(IOU)= 0.5697225701815163
# step) 890 Accuracy(IOU)= 0.5693928822165938
# step) 891 Accuracy(IOU)= 0.5688418859286457
# step) 892 Accuracy(IOU)= 0.5706826703650669
# step) 893 Accuracy(IOU)= 0.5706620314055569
# step) 894 Accuracy(IOU)= 0.5684028099328825
# step) 895 Accuracy(IOU)= 0.5677139303134923
# step) 896 Accuracy(IOU)= 0.5712791730599178
# step) 897 Accuracy(IOU)= 0.574545230978748
# step) 898 Accuracy(IOU)= 0.5757386170316543
# step) 899 Accuracy(IOU)= 0.5779936394754964
# step) 900 Accuracy(IOU)= 0.578331685349075
# step) 901 Accuracy(IOU)= 0.5777122675596482
# step) 902 Accuracy(IOU)= 0.5789093019790071
# step) 903 Accuracy(IOU)= 0.5757830709024621
# step) 904 Accuracy(IOU)= 0.5746343997226466
# step) 905 Accuracy(IOU)= 0.5761890536979085
# step) 906 Accuracy(IOU)= 0.5783510374199246
# step) 907 Accuracy(IOU)= 0.5758823362488732
# step) 908 Accuracy(IOU)= 0.5752596194966826
# step) 909 Accuracy(IOU)= 0.575765667167301
# step) 910 Accuracy(IOU)= 0.5747505881676327
# step) 911 Accuracy(IOU)= 0.5745037356720724
# step) 912 Accuracy(IOU)= 0.5735513567039663
# step) 913 Accuracy(IOU)= 0.5739410691577396
# step) 914 Accuracy(IOU)= 0.5731610495236535
# step) 915 Accuracy(IOU)= 0.5714912368857016
# step) 916 Accuracy(IOU)= 0.5743253448072193
# step) 917 Accuracy(IOU)= 0.5690426870339599
# step) 918 Accuracy(IOU)= 0.5715899040015491
# step) 919 Accuracy(IOU)= 0.5728279835000468
# step) 920 Accuracy(IOU)= 0.571854132826595
# step) 921 Accuracy(IOU)= 0.5725525661620635
# step) 922 Accuracy(IOU)= 0.5760871883104252
# step) 923 Accuracy(IOU)= 0.5723273885956711
# step) 924 Accuracy(IOU)= 0.5724445527180227
# step) 925 Accuracy(IOU)= 0.5713435131242227
# step) 926 Accuracy(IOU)= 0.5740458932271647
# step) 927 Accuracy(IOU)= 0.5760003450595873
# step) 928 Accuracy(IOU)= 0.574988652651777
# step) 929 Accuracy(IOU)= 0.5736561950955962
# step) 930 Accuracy(IOU)= 0.5728090990131133
# step) 931 Accuracy(IOU)= 0.57337568528052
# step) 932 Accuracy(IOU)= 0.5719681008987613
# step) 933 Accuracy(IOU)= 0.5734094864219087
# step) 934 Accuracy(IOU)= 0.5737354798345528
# step) 935 Accuracy(IOU)= 0.5746760917501125
# step) 936 Accuracy(IOU)= 0.57400512707914
# step) 937 Accuracy(IOU)= 0.5757254285867833
# step) 938 Accuracy(IOU)= 0.5748196821434562
# step) 939 Accuracy(IOU)= 0.5766955148391955
# step) 940 Accuracy(IOU)= 0.5744813425243797
# step) 941 Accuracy(IOU)= 0.5717430016867213
# step) 942 Accuracy(IOU)= 0.5738737575667276
# step) 943 Accuracy(IOU)= 0.5738336752387487
# step) 944 Accuracy(IOU)= 0.5718883348929165
# step) 945 Accuracy(IOU)= 0.5728935468885308
# step) 946 Accuracy(IOU)= 0.5709845628347074
# step) 947 Accuracy(IOU)= 0.5706728243774191
# step) 948 Accuracy(IOU)= 0.5724505703157738
# step) 949 Accuracy(IOU)= 0.5696840687892327
# step) 950 Accuracy(IOU)= 0.5718135343252098
# step) 951 Accuracy(IOU)= 0.5723062536315014
# step) 952 Accuracy(IOU)= 0.5759513276203405
# step) 953 Accuracy(IOU)= 0.5787890822102718
# step) 954 Accuracy(IOU)= 0.5781614778147133
# step) 955 Accuracy(IOU)= 0.577754683865004
# step) 956 Accuracy(IOU)= 0.5764048528643093
# step) 957 Accuracy(IOU)= 0.5780549939127689
# step) 958 Accuracy(IOU)= 0.5779121856585548
# step) 959 Accuracy(IOU)= 0.5751728619424951
# step) 960 Accuracy(IOU)= 0.5750612192586627
# step) 961 Accuracy(IOU)= 0.5760725650691202
# step) 962 Accuracy(IOU)= 0.5784562526512323
# step) 963 Accuracy(IOU)= 0.5775811888162788
# step) 964 Accuracy(IOU)= 0.577910581748749
# step) 965 Accuracy(IOU)= 0.5790073771534905
# step) 966 Accuracy(IOU)= 0.5809892823562979
# step) 967 Accuracy(IOU)= 0.5797805116736192
# step) 968 Accuracy(IOU)= 0.5783089529376889
# step) 969 Accuracy(IOU)= 0.576253343581423
# step) 970 Accuracy(IOU)= 0.5760684649841707
# step) 971 Accuracy(IOU)= 0.5750286231726164
# step) 972 Accuracy(IOU)= 0.5773166086064634
# step) 973 Accuracy(IOU)= 0.5721720068781564
# step) 974 Accuracy(IOU)= 0.5737011912502546
# step) 975 Accuracy(IOU)= 0.5729390327341678
# step) 976 Accuracy(IOU)= 0.5719606317843248
# step) 977 Accuracy(IOU)= 0.5708983026333249
# step) 978 Accuracy(IOU)= 0.5714583942854126
# step) 979 Accuracy(IOU)= 0.5708640776145539
# step) 980 Accuracy(IOU)= 0.5703746126539907
# step) 981 Accuracy(IOU)= 0.5711124263190157
# step) 982 Accuracy(IOU)= 0.572815093473901
# step) 983 Accuracy(IOU)= 0.5699394706344074
# step) 984 Accuracy(IOU)= 0.5687190869272661
# step) 985 Accuracy(IOU)= 0.5721328690680566
# step) 986 Accuracy(IOU)= 0.5753067468287921
# step) 987 Accuracy(IOU)= 0.5758800591365051
# step) 988 Accuracy(IOU)= 0.5763268733503616
# step) 989 Accuracy(IOU)= 0.5747755269047989
# step) 990 Accuracy(IOU)= 0.5783875223834316
# step) 991 Accuracy(IOU)= 0.5820290357341975
# step) 992 Accuracy(IOU)= 0.5837389208243196
# step) 993 Accuracy(IOU)= 0.5826186408194151
# step) 994 Accuracy(IOU)= 0.5838082781331067
# step) 995 Accuracy(IOU)= 0.5850875669109187
# step) 996 Accuracy(IOU)= 0.5867966988139836
# step) 997 Accuracy(IOU)= 0.5870428594617995
# step) 998 Accuracy(IOU)= 0.588103896731363
# step) 999 Accuracy(IOU)= 0.5853472971823652
# step) 1000 Accuracy(IOU)= 0.5856847822336128
# step) 1001 Accuracy(IOU)= 0.5844250728757275
# step) 1002 Accuracy(IOU)= 0.5846455399165931
# step) 1003 Accuracy(IOU)= 0.5822495291561562
# step) 1004 Accuracy(IOU)= 0.5830328491559994
# step) 1005 Accuracy(IOU)= 0.5831088641245225
# step) 1006 Accuracy(IOU)= 0.5829999292661218
# step) 1007 Accuracy(IOU)= 0.582827426425792
# step) 1008 Accuracy(IOU)= 0.5817399643439606
# step) 1009 Accuracy(IOU)= 0.5828989831956992
# step) 1010 Accuracy(IOU)= 0.5814458618034166
# step) 1011 Accuracy(IOU)= 0.5808732764496951
# step) 1012 Accuracy(IOU)= 0.5813169457523826
# step) 1013 Accuracy(IOU)= 0.5847350182363107
# step) 1014 Accuracy(IOU)= 0.5842366729186402
# step) 1015 Accuracy(IOU)= 0.5848193125790718
# step) 1016 Accuracy(IOU)= 0.5850484680431782
# step) 1017 Accuracy(IOU)= 0.5853251292491676
# step) 1018 Accuracy(IOU)= 0.5850079549792284
# step) 1019 Accuracy(IOU)= 0.5827135714400257
# step) 1020 Accuracy(IOU)= 0.5837019693636258
# step) 1021 Accuracy(IOU)= 0.5851661294366446
# step) 1022 Accuracy(IOU)= 0.5836961548893523
# step) 1023 Accuracy(IOU)= 0.5842779394542359
# step) 1024 Accuracy(IOU)= 0.5826799870917828
# step) 1025 Accuracy(IOU)= 0.5814396230753
# step) 1026 Accuracy(IOU)= 0.5831006137025334
# step) 1027 Accuracy(IOU)= 0.5855333588338949
# step) 1028 Accuracy(IOU)= 0.5860382711886254
# step) 1029 Accuracy(IOU)= 0.5864541860460141
# step) 1030 Accuracy(IOU)= 0.5826540158906092
# step) 1031 Accuracy(IOU)= 0.57963840485129
# step) 1032 Accuracy(IOU)= 0.5780629535248688
# step) 1033 Accuracy(IOU)= 0.578061647567501
# step) 1034 Accuracy(IOU)= 0.5763253889280725
# step) 1035 Accuracy(IOU)= 0.5742078862170563
# step) 1036 Accuracy(IOU)= 0.576092357552487
# step) 1037 Accuracy(IOU)= 0.5764218675745268
# step) 1038 Accuracy(IOU)= 0.5745120693818939
# step) 1039 Accuracy(IOU)= 0.5751957715630979
# step) 1040 Accuracy(IOU)= 0.5747901186217512
# step) 1041 Accuracy(IOU)= 0.577455888094599
# step) 1042 Accuracy(IOU)= 0.5759038560619691
# step) 1043 Accuracy(IOU)= 0.5739238121808005
# step) 1044 Accuracy(IOU)= 0.5741061929974385
# step) 1045 Accuracy(IOU)= 0.5765397364370319
# step) 1046 Accuracy(IOU)= 0.5785360326695015
# step) 1047 Accuracy(IOU)= 0.5788874563002879
# step) 1048 Accuracy(IOU)= 0.5789315465152315
# step) 1049 Accuracy(IOU)= 0.5794614070087126
# step) 1050 Accuracy(IOU)= 0.5803305552696345
# step) 1051 Accuracy(IOU)= 0.5808227787248498
# step) 1052 Accuracy(IOU)= 0.5811683275832616
# step) 1053 Accuracy(IOU)= 0.581253586922938
# step) 1054 Accuracy(IOU)= 0.579601709472841
# step) 1055 Accuracy(IOU)= 0.5827457113896101
# step) 1056 Accuracy(IOU)= 0.5848699788049804
# step) 1057 Accuracy(IOU)= 0.5856208030380793
# step) 1058 Accuracy(IOU)= 0.5835844829438138
# step) 1059 Accuracy(IOU)= 0.581458785256786
# step) 1060 Accuracy(IOU)= 0.5793242334721808
# step) 1061 Accuracy(IOU)= 0.579375226557686
# step) 1062 Accuracy(IOU)= 0.5770892279027201
# step) 1063 Accuracy(IOU)= 0.5761247069549078
# step) 1064 Accuracy(IOU)= 0.5754585656526088
# step) 1065 Accuracy(IOU)= 0.5749347989829754
# step) 1066 Accuracy(IOU)= 0.5734319260936629
# step) 1067 Accuracy(IOU)= 0.5725922156879738
# step) 1068 Accuracy(IOU)= 0.5719088017756085
# step) 1069 Accuracy(IOU)= 0.572957656067232
# step) 1070 Accuracy(IOU)= 0.5721197051493362
# step) 1071 Accuracy(IOU)= 0.5699563468954122
# step) 1072 Accuracy(IOU)= 0.5734832009679619
# step) 1073 Accuracy(IOU)= 0.5718005335128782
# step) 1074 Accuracy(IOU)= 0.5737993943133466
# step) 1075 Accuracy(IOU)= 0.5772371825738875
# step) 1076 Accuracy(IOU)= 0.5758519632411486
# step) 1077 Accuracy(IOU)= 0.5782815994982483
# step) 1078 Accuracy(IOU)= 0.5813376397235112
# step) 1079 Accuracy(IOU)= 0.5819942163864262
# step) 1080 Accuracy(IOU)= 0.5791688100859614
# step) 1081 Accuracy(IOU)= 0.5783000326158048
# step) 1082 Accuracy(IOU)= 0.5757473745585905
# step) 1083 Accuracy(IOU)= 0.5749549677227946
# step) 1084 Accuracy(IOU)= 0.577540113146351
# ...
# step) 1757 Accuracy(IOU)= 0.5916284503073123
# step) 1758 Accuracy(IOU)= 0.5905083143428286
# step) 1759 Accuracy(IOU)= 0.5938064273673461
# step) 1760 Accuracy(IOU)= 0.5901343338006123
# step) 1761 Accuracy(IOU)= 0.5910102787802864
# step) 1762 Accuracy(IOU)= 0.5917338004269547
# step) 1763 Accuracy(IOU)= 0.5954420153153701
# step) 1764 Accuracy(IOU)= 0.5982648607109224
# step) 1765 Accuracy(IOU)= 0.5987321183337861
# step) 1766 Accuracy(IOU)= 0.600417500416592
# step) 1767 Accuracy(IOU)= 0.5992583232356644
# step) 1768 Accuracy(IOU)= 0.5996246746441922
# step) 1769 Accuracy(IOU)= 0.6001746731150736
# step) 1770 Accuracy(IOU)= 0.6013925711688501
# step) 1771 Accuracy(IOU)= 0.601110322274102
# step) 1772 Accuracy(IOU)= 0.6017933785591124
# step) 1773 Accuracy(IOU)= 0.6004201009548568
# step) 1774 Accuracy(IOU)= 0.5987695069442286
# step) 1775 Accuracy(IOU)= 0.5974515228685531
# step) 1776 Accuracy(IOU)= 0.5983427176599329
# step) 1777 Accuracy(IOU)= 0.5996773204830664
# step) 1778 Accuracy(IOU)= 0.5978474087527498
# step) 1779 Accuracy(IOU)= 0.5977031553130342
# step) 1780 Accuracy(IOU)= 0.5982847142912531
# step) 1781 Accuracy(IOU)= 0.5977594222039588
# step) 1782 Accuracy(IOU)= 0.5995419450359049
# step) 1783 Accuracy(IOU)= 0.6011804822563068
# step) 1784 Accuracy(IOU)= 0.5997364913070348
# step) 1785 Accuracy(IOU)= 0.5981173638202454
# step) 1786 Accuracy(IOU)= 0.5974042346537836
# step) 1787 Accuracy(IOU)= 0.5986902621543526
# step) 1788 Accuracy(IOU)= 0.5979281423573254
# step) 1789 Accuracy(IOU)= 0.5956873187923145
# step) 1790 Accuracy(IOU)= 0.597680758099623
# step) 1791 Accuracy(IOU)= 0.6003135589304156
# step) 1792 Accuracy(IOU)= 0.5984487815764706
# step) 1793 Accuracy(IOU)= 0.5999917631572972
# step) 1794 Accuracy(IOU)= 0.6005455514564341
# step) 1795 Accuracy(IOU)= 0.6034342950747891
# step) 1796 Accuracy(IOU)= 0.5996536910638033
# step) 1797 Accuracy(IOU)= 0.6003094461663335
# step) 1798 Accuracy(IOU)= 0.5984809513521921
# step) 1799 Accuracy(IOU)= 0.6006688213821655
# step) 1800 Accuracy(IOU)= 0.6021957478038114
# step) 1801 Accuracy(IOU)= 0.6014899351498012
# step) 1802 Accuracy(IOU)= 0.6002213244554916
# step) 1803 Accuracy(IOU)= 0.5978878897496406
# step) 1804 Accuracy(IOU)= 0.6013300041802386
# step) 1805 Accuracy(IOU)= 0.6011173792921686
# step) 1806 Accuracy(IOU)= 0.6034276469112189
# step) 1807 Accuracy(IOU)= 0.6051766909882569
# step) 1808 Accuracy(IOU)= 0.6018687926081708
# step) 1809 Accuracy(IOU)= 0.6022471362277282
# step) 1810 Accuracy(IOU)= 0.6040183661565351
# step) 1811 Accuracy(IOU)= 0.6055144280794578
# step) 1812 Accuracy(IOU)= 0.6081468074021026
# step) 1813 Accuracy(IOU)= 0.6077144964945627
# step) 1814 Accuracy(IOU)= 0.6094094431567381
# step) 1815 Accuracy(IOU)= 0.6085859567926832
# step) 1816 Accuracy(IOU)= 0.606696645090624
# step) 1817 Accuracy(IOU)= 0.60606660273964
# step) 1818 Accuracy(IOU)= 0.6091595936717773
# step) 1819 Accuracy(IOU)= 0.6088011181764963
# step) 1820 Accuracy(IOU)= 0.6040620095778536
# step) 1821 Accuracy(IOU)= 0.6050472500300945
# step) 1822 Accuracy(IOU)= 0.6056080007506187
# step) 1823 Accuracy(IOU)= 0.6053084509087848
# step) 1824 Accuracy(IOU)= 0.6047859991339957
# step) 1825 Accuracy(IOU)= 0.6041281716724867
# step) 1826 Accuracy(IOU)= 0.6053457134697464
# step) 1827 Accuracy(IOU)= 0.6023238856590083
# step) 1828 Accuracy(IOU)= 0.6018601287808347
# step) 1829 Accuracy(IOU)= 0.60397765329602
# step) 1830 Accuracy(IOU)= 0.6040262468478225
# step) 1831 Accuracy(IOU)= 0.6002290748003056
# step) 1832 Accuracy(IOU)= 0.5995902180094025
# step) 1833 Accuracy(IOU)= 0.599120540800126
# step) 1834 Accuracy(IOU)= 0.6023616055136991
# step) 1835 Accuracy(IOU)= 0.6009674169511806
# step) 1836 Accuracy(IOU)= 0.5981575758171378
# step) 1837 Accuracy(IOU)= 0.6008465810421284
# step) 1838 Accuracy(IOU)= 0.6012836560174967
# step) 1839 Accuracy(IOU)= 0.6040024051983648
# step) 1840 Accuracy(IOU)= 0.6041529219369389
# step) 1841 Accuracy(IOU)= 0.6055231122781927
# step) 1842 Accuracy(IOU)= 0.6033674301032218
# step) 1843 Accuracy(IOU)= 0.6027077916374557
# step) 1844 Accuracy(IOU)= 0.6009071193416561
# step) 1845 Accuracy(IOU)= 0.5985508645630726
# step) 1846 Accuracy(IOU)= 0.5989344573225855
# step) 1847 Accuracy(IOU)= 0.5980994029486395
# step) 1848 Accuracy(IOU)= 0.5998975857503985
# step) 1849 Accuracy(IOU)= 0.5998907953663366
# step) 1850 Accuracy(IOU)= 0.5975597817164718
# step) 1851 Accuracy(IOU)= 0.5977488646186827
# step) 1852 Accuracy(IOU)= 0.6001201705520017
# step) 1853 Accuracy(IOU)= 0.6028865057250675
# step) 1854 Accuracy(IOU)= 0.6029483585795371
# step) 1855 Accuracy(IOU)= 0.6032625168709161
# step) 1856 Accuracy(IOU)= 0.6050227621045431
# step) 1857 Accuracy(IOU)= 0.6033381750641518
# step) 1858 Accuracy(IOU)= 0.6019798189554284
# step) 1859 Accuracy(IOU)= 0.6037265608163807
# step) 1860 Accuracy(IOU)= 0.602598915493251
# step) 1861 Accuracy(IOU)= 0.6038877919274603
# step) 1862 Accuracy(IOU)= 0.6039995977688287
# step) 1863 Accuracy(IOU)= 0.604098477275607
# step) 1864 Accuracy(IOU)= 0.6040308679424947
# step) 1865 Accuracy(IOU)= 0.6056994926164938
# step) 1866 Accuracy(IOU)= 0.6045508159118979
# step) 1867 Accuracy(IOU)= 0.603960753996065
# step) 1868 Accuracy(IOU)= 0.6047142466939507
# step) 1869 Accuracy(IOU)= 0.6052080082721162
# step) 1870 Accuracy(IOU)= 0.608369676763652
# step) 1871 Accuracy(IOU)= 0.6077759426930445
# step) 1872 Accuracy(IOU)= 0.606289937344979
# step) 1873 Accuracy(IOU)= 0.6078810074978201
# step) 1874 Accuracy(IOU)= 0.6076415887735881
# step) 1875 Accuracy(IOU)= 0.6093530579556993
# step) 1876 Accuracy(IOU)= 0.6104784414081247
# step) 1877 Accuracy(IOU)= 0.6132612608730184
# step) 1878 Accuracy(IOU)= 0.6113768897484533
# step) 1879 Accuracy(IOU)= 0.611989986023355
# step) 1880 Accuracy(IOU)= 0.6116939201055348
# step) 1881 Accuracy(IOU)= 0.6091911013878779
# step) 1882 Accuracy(IOU)= 0.6094094095426622
# step) 1883 Accuracy(IOU)= 0.6097886623958593
# step) 1884 Accuracy(IOU)= 0.6076859120924917
# step) 1885 Accuracy(IOU)= 0.6081472605025421
# step) 1886 Accuracy(IOU)= 0.6078623717884315
# step) 1887 Accuracy(IOU)= 0.6075085584324094
# step) 1888 Accuracy(IOU)= 0.6095314361812151
# step) 1889 Accuracy(IOU)= 0.6092049043158552
# step) 1890 Accuracy(IOU)= 0.6125901863149864
# step) 1891 Accuracy(IOU)= 0.6117067132314385
# step) 1892 Accuracy(IOU)= 0.611346364615474
# step) 1893 Accuracy(IOU)= 0.609243227235608
# step) 1894 Accuracy(IOU)= 0.6078976629775875
# step) 1895 Accuracy(IOU)= 0.6069537284191542
# step) 1896 Accuracy(IOU)= 0.6075029996428819
# step) 1897 Accuracy(IOU)= 0.6088337072849266
# step) 1898 Accuracy(IOU)= 0.6096616142420761
# step) 1899 Accuracy(IOU)= 0.6078572650645677
# step) 1900 Accuracy(IOU)= 0.6074892286554534
# step) 1901 Accuracy(IOU)= 0.6099833778594537
# step) 1902 Accuracy(IOU)= 0.6109506170684156
# step) 1903 Accuracy(IOU)= 0.609179340196323
# step) 1904 Accuracy(IOU)= 0.6086656683372904
# step) 1905 Accuracy(IOU)= 0.6116473481407338
# step) 1906 Accuracy(IOU)= 0.6102046429412632
# step) 1907 Accuracy(IOU)= 0.6121709977293113
# step) 1908 Accuracy(IOU)= 0.6147762720144846
# step) 1909 Accuracy(IOU)= 0.613790015231916
# step) 1910 Accuracy(IOU)= 0.61126105830355
# step) 1911 Accuracy(IOU)= 0.6113768154067862
# step) 1912 Accuracy(IOU)= 0.6088683611498513
# step) 1913 Accuracy(IOU)= 0.6084126937670287
# step) 1914 Accuracy(IOU)= 0.609088101307546
# step) 1915 Accuracy(IOU)= 0.6053774840998599
# step) 1916 Accuracy(IOU)= 0.6083780440185735
# step) 1917 Accuracy(IOU)= 0.6099464342364993
# step) 1918 Accuracy(IOU)= 0.6101567783867948
# step) 1919 Accuracy(IOU)= 0.6094023277885195
# step) 1920 Accuracy(IOU)= 0.6099526422839574
# step) 1921 Accuracy(IOU)= 0.6095363674804568
# step) 1922 Accuracy(IOU)= 0.6105056151213795
# step) 1923 Accuracy(IOU)= 0.612874191901875
# step) 1924 Accuracy(IOU)= 0.6116230616795763
# step) 1925 Accuracy(IOU)= 0.6113741513619291
# step) 1926 Accuracy(IOU)= 0.611630373136617
# step) 1927 Accuracy(IOU)= 0.6120047857434084
# step) 1928 Accuracy(IOU)= 0.6117761944899782
# step) 1929 Accuracy(IOU)= 0.6104050943273431
# step) 1930 Accuracy(IOU)= 0.6114333238530104
# step) 1931 Accuracy(IOU)= 0.612470357682771
# step) 1932 Accuracy(IOU)= 0.6132765704153
# step) 1933 Accuracy(IOU)= 0.6117519911945302
# step) 1934 Accuracy(IOU)= 0.613856716260536
# step) 1935 Accuracy(IOU)= 0.6135944154582135
# step) 1936 Accuracy(IOU)= 0.6141711106354489
# step) 1937 Accuracy(IOU)= 0.6170088011175343
# step) 1938 Accuracy(IOU)= 0.6161166316835531
# step) 1939 Accuracy(IOU)= 0.6163113446735109
# step) 1940 Accuracy(IOU)= 0.618233036238525
# step) 1941 Accuracy(IOU)= 0.61677847477415
# step) 1942 Accuracy(IOU)= 0.617005846409923
# step) 1943 Accuracy(IOU)= 0.6132823239205647
# step) 1944 Accuracy(IOU)= 0.6130960462822502
# step) 1945 Accuracy(IOU)= 0.6136469465047762
# step) 1946 Accuracy(IOU)= 0.6139145228599647
# step) 1947 Accuracy(IOU)= 0.6140808784963476
# step) 1948 Accuracy(IOU)= 0.6154628178240626
# step) 1949 Accuracy(IOU)= 0.6149430256043028
# step) 1950 Accuracy(IOU)= 0.6158643256768196
# step) 1951 Accuracy(IOU)= 0.6145437735550764
# step) 1952 Accuracy(IOU)= 0.6168564262440633
# step) 1953 Accuracy(IOU)= 0.616225647869341
# step) 1954 Accuracy(IOU)= 0.6193718165787122
# step) 1955 Accuracy(IOU)= 0.6142145161952317
# step) 1956 Accuracy(IOU)= 0.6143447793994827
# step) 1957 Accuracy(IOU)= 0.6175857282777368
# step) 1958 Accuracy(IOU)= 0.6161318037041765
# step) 1959 Accuracy(IOU)= 0.6144403136767401
# step) 1960 Accuracy(IOU)= 0.6145910753635048
# step) 1961 Accuracy(IOU)= 0.6148013526687229
# step) 1962 Accuracy(IOU)= 0.613595190340709
# step) 1963 Accuracy(IOU)= 0.6109009113584826
# step) 1964 Accuracy(IOU)= 0.6081791838415583
# step) 1965 Accuracy(IOU)= 0.6058208825393556
# step) 1966 Accuracy(IOU)= 0.6045215097449221
# step) 1967 Accuracy(IOU)= 0.6071802387345013
# step) 1968 Accuracy(IOU)= 0.6093585619937475
# step) 1969 Accuracy(IOU)= 0.6111150249158328
# step) 1970 Accuracy(IOU)= 0.6138264421295956
# step) 1971 Accuracy(IOU)= 0.6149948142801838
# step) 1972 Accuracy(IOU)= 0.6165447944210732
# step) 1973 Accuracy(IOU)= 0.6133029867876268
# step) 1974 Accuracy(IOU)= 0.6126705578537792
# step) 1975 Accuracy(IOU)= 0.6114221267756115
# step) 1976 Accuracy(IOU)= 0.6078929392822313
# step) 1977 Accuracy(IOU)= 0.609535151466176
# step) 1978 Accuracy(IOU)= 0.6069314838518705
# step) 1979 Accuracy(IOU)= 0.60820036028418
# step) 1980 Accuracy(IOU)= 0.6060767434601697
# step) 1981 Accuracy(IOU)= 0.6086610193986759
# step) 1982 Accuracy(IOU)= 0.6074579506694947
# step) 1983 Accuracy(IOU)= 0.6090344182733572
# step) 1984 Accuracy(IOU)= 0.6080344240032671
# step) 1985 Accuracy(IOU)= 0.6077522908609517
# step) 1986 Accuracy(IOU)= 0.6058820085934593
# step) 1987 Accuracy(IOU)= 0.6028760129451429
# step) 1988 Accuracy(IOU)= 0.6056008112129846
# step) 1989 Accuracy(IOU)= 0.6073869146883792
# step) 1990 Accuracy(IOU)= 0.6102335493962471
# step) 1991 Accuracy(IOU)= 0.609669049261858
# step) 1992 Accuracy(IOU)= 0.6095306959570065
# step) 1993 Accuracy(IOU)= 0.6110054143222579
# step) 1994 Accuracy(IOU)= 0.6095478832794113
# step) 1995 Accuracy(IOU)= 0.6097682598304902
# step) 1996 Accuracy(IOU)= 0.6083298228424224
# step) 1997 Accuracy(IOU)= 0.6072387581287839
# step) 1998 Accuracy(IOU)= 0.606410604155742
# step) 1999 Accuracy(IOU)= 0.6066221906963151
# step) 2000 Accuracy(IOU)= 0.6047120045702586
# step) 2001 Accuracy(IOU)= 0.6035160499384126
# step) 2002 Accuracy(IOU)= 0.6012508918637454
# step) 2003 Accuracy(IOU)= 0.6041584326124663
# step) 2004 Accuracy(IOU)= 0.6041698203646649
# step) 2005 Accuracy(IOU)= 0.6017150620323295
# step) 2006 Accuracy(IOU)= 0.6004438299243506
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 37
#      35 predictor.model.zero_grad() # empty gradient
#      36 scaler.scale(loss).backward()  # Backpropogate
# ---> 37 scaler.step(optimizer)
#      38 scaler.update() # Mix precision
#      40 if itr%1000==0: torch.save(predictor.model.state_dict(), "model.torch") # save model
#
# File D:\vpy\Lib\site-packages\torch\amp\grad_scaler.py:453, in GradScaler.step(self, optimizer, *args, **kwargs)
#     447     self.unscale_(optimizer)
#     449 assert (
#     450     len(optimizer_state["found_inf_per_device"]) > 0
#     451 ), "No inf checks were recorded for this optimizer."
# --> 453 retval = self._maybe_opt_step(optimizer, optimizer_state, *args, **kwargs)
#     455 optimizer_state["stage"] = OptState.STEPPED
#     457 return retval
#
# File D:\vpy\Lib\site-packages\torch\amp\grad_scaler.py:351, in GradScaler._maybe_opt_step(self, optimizer, optimizer_state, *args, **kwargs)
#     349 retval: Optional[float] = None
#     350 if not sum(v.item() for v in optimizer_state["found_inf_per_device"].values()):
# --> 351     retval = optimizer.step(*args, **kwargs)
#     352 return retval
#
# File D:\vpy\Lib\site-packages\torch\optim\optimizer.py:391, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     386         else:
#     387             raise RuntimeError(
#     388                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     389             )
# --> 391 out = func(*args, **kwargs)
#     392 self._optimizer_step_code()
#     394 # call optimizer step post hooks
#
# File D:\vpy\Lib\site-packages\torch\optim\optimizer.py:76, in _use_grad_for_differentiable.<locals>._use_grad(self, *args, **kwargs)
#      74     torch.set_grad_enabled(self.defaults['differentiable'])
#      75     torch._dynamo.graph_break()
# ---> 76     ret = func(self, *args, **kwargs)
#      77 finally:
#      78     torch._dynamo.graph_break()
#
# File D:\vpy\Lib\site-packages\torch\optim\adamw.py:188, in AdamW.step(self, closure)
#     175     beta1, beta2 = group["betas"]
#     177     has_complex = self._init_group(
#     178         group,
#     179         params_with_grad,
#    (...)
#     185         state_steps,
#     186     )
# --> 188     adamw(
#     189         params_with_grad,
#     190         grads,
#     191         exp_avgs,
#     192         exp_avg_sqs,
#     193         max_exp_avg_sqs,
#     194         state_steps,
#     195         amsgrad=amsgrad,
#     196         beta1=beta1,
#     197         beta2=beta2,
#     198         lr=group["lr"],
#     199         weight_decay=group["weight_decay"],
#     200         eps=group["eps"],
#     201         maximize=group["maximize"],
#     202         foreach=group["foreach"],
#     203         capturable=group["capturable"],
#     204         differentiable=group["differentiable"],
#     205         fused=group["fused"],
#     206         grad_scale=getattr(self, "grad_scale", None),
#     207         found_inf=getattr(self, "found_inf", None),
#     208         has_complex=has_complex,
#     209     )
#     211 return loss
#
# File D:\vpy\Lib\site-packages\torch\optim\adamw.py:340, in adamw(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, has_complex, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     337 else:
#     338     func = _single_tensor_adamw
# --> 340 func(
#     341     params,
#     342     grads,
#     343     exp_avgs,
#     344     exp_avg_sqs,
#     345     max_exp_avg_sqs,
#     346     state_steps,
#     347     amsgrad=amsgrad,
#     348     beta1=beta1,
#     349     beta2=beta2,
#     350     lr=lr,
#     351     weight_decay=weight_decay,
#     352     eps=eps,
#     353     maximize=maximize,
#     354     capturable=capturable,
#     355     differentiable=differentiable,
#     356     grad_scale=grad_scale,
#     357     found_inf=found_inf,
#     358     has_complex=has_complex,
#     359 )
#
# File D:\vpy\Lib\site-packages\torch\optim\adamw.py:596, in _multi_tensor_adamw(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable, has_complex)
#     594 else:
#     595     bias_correction1 = [1 - beta1 ** _get_value(step) for step in device_state_steps]
# --> 596     bias_correction2 = [1 - beta2 ** _get_value(step) for step in device_state_steps]
#     598     step_size = _stack_if_compiling([(lr / bc) * -1 for bc in bias_correction1])
#     600     bias_correction2_sqrt = [_dispatch_sqrt(bc) for bc in bias_correction2]
#
# File D:\vpy\Lib\site-packages\torch\optim\optimizer.py:89, in _get_value(x)
#      87     return x
#      88 else:
# ---> 89     return x.item()
#
# KeyboardInterrupt:
